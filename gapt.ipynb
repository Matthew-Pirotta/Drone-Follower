# %% [markdown]
# ## Getting to follow a red spot

# %%
import cv2
import numpy as np

# Start video capture (0 for webcam or drone feed URL if available)
# The 0 needs to be changed with the url of the drones camera
# This will open the camera that I will be using 
cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    if not ret:
        break

    # Convert the frame to HSV for better color detection
    hsv_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)

    # Define red color range (tune values as needed)
    lower_red = np.array([0, 120, 70])
    upper_red = np.array([10, 255, 255])

    # Create a mask for red color
    mask = cv2.inRange(hsv_frame, lower_red, upper_red)

    # Find contours of the red object
    contours, _ = cv2.findContours(mask, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    # For each contour 
    for contour in contours:
        # Calculate area of the contour and filter noise 
        area = cv2.contourArea(contour)
        # Minimum size to filter noise
        if area > 100:  
            # Draw a circle around the centroid of the contour
            x, y, w, h = cv2.boundingRect(contour)
            # Draw rectangle around the red object
            cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)
            # Print the position of the red object
            print(f"Red spot position: x={x}, y={y}")

            # Determine position relative to the center of the frame
            frame_center_x, frame_center_y = frame.shape[1] // 2, frame.shape[0] // 2
            # //2 Rounds down this can be changed according the the implementation 
            offset_x = x + w//2 - frame_center_x
            offset_y = y + h//2 - frame_center_y

            # Use offset to decide drone movement (e.g., up, down, left, right)
            print(f"Offset: x={offset_x}, y={offset_y}")

    # Display the video feed
    cv2.imshow("Red Spot Tracking", frame)

    # Break loop on 'q' key press
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
import requests

API_URL = "https://api.dji.com/v1/control"
API_KEY = "your_api_key_here"

def send_movement_command(yaw, pitch, roll, throttle):
    payload = {
        "yaw": yaw,
        "pitch": pitch,
        "roll": roll,
        "throttle": throttle
    }
    headers = {"Authorization": f"Bearer {API_KEY}"}
    response = requests.post(API_URL, json=payload, headers=headers)
    if response.status_code == 200:
        print("Command sent successfully.")
    else:
        print(f"Error: {response.status_code} - {response.text}")

# Example offsets translated into movement
send_movement_command(0, offset_y / MAX_FRAME_HEIGHT, offset_x / MAX_FRAME_WIDTH, 0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 21
#      18         print(f"Error: {response.status_code} - {response.text}")
#      20 # Example offsets translated into movement
# ---> 21 send_movement_command(0, offset_y / MAX_FRAME_HEIGHT, offset_x / MAX_FRAME_WIDTH, 0)
#
# NameError: name 'offset_y' is not defined

# %% [markdown]
# ## Getting the drone to track a person (either as a person or maybe accessory like the hat with a cross thing he was talking about) and hover behind them wherever they go (slow movement)

# %% [markdown]
# ### Note that the contour changes the shape of the thing that we are searching from here I changed the shape of the thing to be searched from.

# %%
import cv2
import numpy as np

# Start video capture (change 0 to camera URL if using drone)
cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    if not ret:
        break

    # Convert to HSV for better color filtering
    hsv_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)

    # Define red color range (tweak these values if needed)
    lower_red1 = np.array([0, 120, 70])
    upper_red1 = np.array([10, 255, 255])
    lower_red2 = np.array([170, 120, 70]) 
    upper_red2 = np.array([180, 255, 255])

    # Create masks for red color
    mask1 = cv2.inRange(hsv_frame, lower_red1, upper_red1)
    mask2 = cv2.inRange(hsv_frame, lower_red2, upper_red2)
    mask = mask1 + mask2  # Combine both masks

    # Apply morphological operations to clean up noise
    kernel = np.ones((5, 5), np.uint8)
    mask = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernel)

    # Find contours in the red mask
    contours, _ = cv2.findContours(mask, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

    for contour in contours:
        area = cv2.contourArea(contour)
        if area > 500:  # Ignore small objects
            # Get bounding box
            x, y, w, h = cv2.boundingRect(contour)
            
            # Aspect ratio check (Crosses tend to have width ≈ height)
            aspect_ratio = float(w) / h
            # Aspect ratio for a cross
            # Changed this to represent a cross 
            if 0.5 < aspect_ratio < 1.5:  
                # Draw rectangle around detected cross
                cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0), 2)
                
                # Find center of the cross
                center_x, center_y = x + w // 2, y + h // 2
                
                # Print detected cross position
                print(f"Red Cross Found at: x={center_x}, y={center_y}")

                # Find offset from center of the frame
                # //2 Rounds down this can be changed according the the implementation 
                frame_center_x, frame_center_y = frame.shape[1] // 2, frame.shape[0] // 2
                offset_x = center_x - frame_center_x
                offset_y = center_y - frame_center_y

                # Use offset to decide drone movement (e.g., up, down, left, right)
                print(f"Offset: x={offset_x}, y={offset_y}")

    # Display the processed frame
    # Display the video feed
    # cv2.imshow("Red Cross Detection", frame)

    # Break loop on 'q' key press
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Red Cross Found at: x=1197, y=684
# Offset: x=557, y=324
# Red Cross Found at: x=758, y=654
# Offset: x=118, y=294
# Red Cross Found at: x=1206, y=625
# Offset: x=566, y=265
# Red Cross Found at: x=966, y=499
# Offset: x=326, y=139
# Red Cross Found at: x=1010, y=450
# Offset: x=370, y=90
# Red Cross Found at: x=1198, y=694
# Offset: x=558, y=334
# Red Cross Found at: x=81, y=337
# Offset: x=-559, y=-23
# Red Cross Found at: x=286, y=298
# Offset: x=-354, y=-62
# Red Cross Found at: x=739, y=643
# Offset: x=99, y=283
# Red Cross Found at: x=957, y=665
# Offset: x=317, y=305
# Red Cross Found at: x=1093, y=607
# Offset: x=453, y=247
# Red Cross Found at: x=1047, y=284
# Offset: x=407, y=-76
# Red Cross Found at: x=1107, y=245
# Offset: x=467, y=-115
# Red Cross Found at: x=960, y=250
# Offset: x=320, y=-110
# Red Cross Found at: x=1237, y=226
# Offset: x=597, y=-134
# Red Cross Found at: x=144, y=319
# Offset: x=-496, y=-41
# Red Cross Found at: x=295, y=202
# Offset: x=-345, y=-158
# Red Cross Found at: x=320, y=180
# Offset: x=-320, y=-180
# Red Cross Found at: x=957, y=679
# Offset: x=317, y=319
# Red Cross Found at: x=741, y=645
# Offset: x=101, y=285
# Red Cross Found at: x=1083, y=584
# Offset: x=443, y=224
# Red Cross Found at: x=1084, y=291
# Offset: x=444, y=-69
# Red Cross Found at: x=1077, y=228
# Offset: x=437, y=-132
# Red Cross Found at: x=1131, y=242
# Offset: x=491, y=-118
# Red Cross Found at: x=1193, y=253
# Offset: x=553, y=-107
# Red Cross Found at: x=63, y=277
# Offset: x=-577, y=-83
# Red Cross Found at: x=445, y=297
# Offset: x=-195, y=-63
# Red Cross Found at: x=26, y=267
# Offset: x=-614, y=-93
# Red Cross Found at: x=259, y=263
# Offset: x=-381, y=-97
# Red Cross Found at: x=356, y=183
# Offset: x=-284, y=-177
# Red Cross Found at: x=974, y=697
# Offset: x=334, y=337
# Red Cross Found at: x=943, y=679
# Offset: x=303, y=319
# Red Cross Found at: x=1104, y=619
# Offset: x=464, y=259
# Red Cross Found at: x=1191, y=255
# Offset: x=551, y=-105
# Red Cross Found at: x=1253, y=267
# Offset: x=613, y=-93
# Red Cross Found at: x=972, y=243
# Offset: x=332, y=-117
# Red Cross Found at: x=96, y=300
# Offset: x=-544, y=-60
# Red Cross Found at: x=28, y=288
# Offset: x=-612, y=-72
# Red Cross Found at: x=348, y=182
# Offset: x=-292, y=-178
# Red Cross Found at: x=953, y=656
# Offset: x=313, y=296
# Red Cross Found at: x=1107, y=613
# Offset: x=467, y=253
# Red Cross Found at: x=1231, y=359
# Offset: x=591, y=-1
# Red Cross Found at: x=777, y=304
# Offset: x=137, y=-56
# Red Cross Found at: x=824, y=350
# Offset: x=184, y=-10
# Red Cross Found at: x=825, y=322
# Offset: x=185, y=-38
# Red Cross Found at: x=1074, y=195
# Offset: x=434, y=-165
# Red Cross Found at: x=1192, y=258
# Offset: x=552, y=-102
# Red Cross Found at: x=987, y=242
# Offset: x=347, y=-118
# Red Cross Found at: x=25, y=315
# Offset: x=-615, y=-45
# Red Cross Found at: x=255, y=255
# Offset: x=-385, y=-105
# Red Cross Found at: x=75, y=239
# Offset: x=-565, y=-121
# Red Cross Found at: x=1067, y=611
# Offset: x=427, y=251
# Red Cross Found at: x=1191, y=309
# Offset: x=551, y=-51
# Red Cross Found at: x=1122, y=229
# Offset: x=482, y=-131
# Red Cross Found at: x=1080, y=238
# Offset: x=440, y=-122
# Red Cross Found at: x=1213, y=229
# Offset: x=573, y=-131
# Red Cross Found at: x=989, y=232
# Offset: x=349, y=-128
# Red Cross Found at: x=97, y=291
# Offset: x=-543, y=-69
# Red Cross Found at: x=31, y=276
# Offset: x=-609, y=-84
# Red Cross Found at: x=75, y=258
# Offset: x=-565, y=-102
# Red Cross Found at: x=78, y=211
# Offset: x=-562, y=-149
# Red Cross Found at: x=56, y=190
# Offset: x=-584, y=-170
# Red Cross Found at: x=820, y=553
# Offset: x=180, y=193
# Red Cross Found at: x=1075, y=609
# Offset: x=435, y=249
# Red Cross Found at: x=1037, y=655
# Offset: x=397, y=295
# Red Cross Found at: x=1195, y=272
# Offset: x=555, y=-88
# Red Cross Found at: x=992, y=233
# Offset: x=352, y=-127
# Red Cross Found at: x=96, y=294
# Offset: x=-544, y=-66
# Red Cross Found at: x=93, y=195
# Offset: x=-547, y=-165
# Red Cross Found at: x=1038, y=656
# Offset: x=398, y=296
# Red Cross Found at: x=1169, y=309
# Offset: x=529, y=-51
# Red Cross Found at: x=1231, y=216
# Offset: x=591, y=-144
# Red Cross Found at: x=955, y=235
# Offset: x=315, y=-125
# Red Cross Found at: x=195, y=261
# Offset: x=-445, y=-99
# Red Cross Found at: x=242, y=288
# Offset: x=-398, y=-72
# Red Cross Found at: x=92, y=201
# Offset: x=-548, y=-159
# Red Cross Found at: x=234, y=196
# Offset: x=-406, y=-164
# Red Cross Found at: x=1030, y=89
# Offset: x=390, y=-271
# Red Cross Found at: x=798, y=678
# Offset: x=158, y=318
# Red Cross Found at: x=826, y=550
# Offset: x=186, y=190
# Red Cross Found at: x=1041, y=589
# Offset: x=401, y=229
# Red Cross Found at: x=1039, y=657
# Offset: x=399, y=297
# Red Cross Found at: x=898, y=420
# Offset: x=258, y=60
# Red Cross Found at: x=1227, y=343
# Offset: x=587, y=-17
# Red Cross Found at: x=1157, y=306
# Offset: x=517, y=-54
# Red Cross Found at: x=1232, y=215
# Offset: x=592, y=-145
# Red Cross Found at: x=1244, y=240
# Offset: x=604, y=-120
# Red Cross Found at: x=972, y=237
# Offset: x=332, y=-123
# Red Cross Found at: x=1019, y=199
# Offset: x=379, y=-161
# Red Cross Found at: x=98, y=96
# Offset: x=-542, y=-264
# Red Cross Found at: x=171, y=280
# Offset: x=-469, y=-80
# Red Cross Found at: x=231, y=274
# Offset: x=-409, y=-86
# Red Cross Found at: x=98, y=203
# Offset: x=-542, y=-157
# Red Cross Found at: x=954, y=701
# Offset: x=314, y=341
# Red Cross Found at: x=1032, y=582
# Offset: x=392, y=222
# Red Cross Found at: x=1088, y=293
# Offset: x=448, y=-67
# Red Cross Found at: x=1165, y=299
# Offset: x=525, y=-61
# Red Cross Found at: x=1075, y=219
# Offset: x=435, y=-141
# Red Cross Found at: x=945, y=247
# Offset: x=305, y=-113
# Red Cross Found at: x=1233, y=230
# Offset: x=593, y=-130
# Red Cross Found at: x=1021, y=228
# Offset: x=381, y=-132
# Red Cross Found at: x=173, y=211
# Offset: x=-467, y=-149
# Red Cross Found at: x=142, y=194
# Offset: x=-498, y=-166
# Red Cross Found at: x=93, y=196
# Offset: x=-547, y=-164
# Red Cross Found at: x=236, y=183
# Offset: x=-404, y=-177
# Red Cross Found at: x=964, y=698
# Offset: x=324, y=338
# Red Cross Found at: x=656, y=595
# Offset: x=16, y=235
# Red Cross Found at: x=862, y=528
# Offset: x=222, y=168
# Red Cross Found at: x=1049, y=580
# Offset: x=409, y=220
# Red Cross Found at: x=1056, y=652
# Offset: x=416, y=292
# Red Cross Found at: x=1156, y=280
# Offset: x=516, y=-80
# Red Cross Found at: x=1091, y=220
# Offset: x=451, y=-140
# Red Cross Found at: x=972, y=238
# Offset: x=332, y=-122
# Red Cross Found at: x=991, y=211
# Offset: x=351, y=-149
# Red Cross Found at: x=1234, y=227
# Offset: x=594, y=-133
# Red Cross Found at: x=827, y=349
# Offset: x=187, y=-11
# Red Cross Found at: x=170, y=244
# Offset: x=-470, y=-116
# Red Cross Found at: x=122, y=205
# Offset: x=-518, y=-155
# Red Cross Found at: x=210, y=192
# Offset: x=-430, y=-168
# Red Cross Found at: x=31, y=617
# Offset: x=-609, y=257
# Red Cross Found at: x=848, y=543
# Offset: x=208, y=183
# Red Cross Found at: x=1048, y=594
# Offset: x=408, y=234
# Red Cross Found at: x=1045, y=641
# Offset: x=405, y=281
# Red Cross Found at: x=1160, y=277
# Offset: x=520, y=-83
# Red Cross Found at: x=972, y=238
# Offset: x=332, y=-122
# Red Cross Found at: x=995, y=210
# Offset: x=355, y=-150
# Red Cross Found at: x=1032, y=95
# Offset: x=392, y=-265
# Red Cross Found at: x=223, y=237
# Offset: x=-417, y=-123
# Red Cross Found at: x=170, y=226
# Offset: x=-470, y=-134
# Red Cross Found at: x=132, y=195
# Offset: x=-508, y=-165
# Red Cross Found at: x=653, y=595
# Offset: x=13, y=235
# Red Cross Found at: x=34, y=608
# Offset: x=-606, y=248
# Red Cross Found at: x=917, y=571
# Offset: x=277, y=211
# Red Cross Found at: x=1047, y=646
# Offset: x=407, y=286
# Red Cross Found at: x=888, y=514
# Offset: x=248, y=154
# Red Cross Found at: x=1256, y=367
# Offset: x=616, y=7
# Red Cross Found at: x=1151, y=315
# Offset: x=511, y=-45
# Red Cross Found at: x=1120, y=244
# Offset: x=480, y=-116
# Red Cross Found at: x=691, y=304
# Offset: x=51, y=-56
# Red Cross Found at: x=968, y=239
# Offset: x=328, y=-121
# Red Cross Found at: x=1224, y=188
# Offset: x=584, y=-172
# Red Cross Found at: x=79, y=384
# Offset: x=-561, y=24
# Red Cross Found at: x=173, y=214
# Offset: x=-467, y=-146
# Red Cross Found at: x=131, y=195
# Offset: x=-509, y=-165
# Red Cross Found at: x=1033, y=96
# Offset: x=393, y=-264
# Red Cross Found at: x=18, y=61
# Offset: x=-622, y=-299
# Red Cross Found at: x=211, y=700
# Offset: x=-429, y=340
# Red Cross Found at: x=28, y=603
# Offset: x=-612, y=243
# Red Cross Found at: x=1057, y=648
# Offset: x=417, y=288
# Red Cross Found at: x=1150, y=321
# Offset: x=510, y=-39
# Red Cross Found at: x=968, y=240
# Offset: x=328, y=-120
# Red Cross Found at: x=1000, y=207
# Offset: x=360, y=-153
# Red Cross Found at: x=1231, y=178
# Offset: x=591, y=-182
# Red Cross Found at: x=93, y=289
# Offset: x=-547, y=-71
# Red Cross Found at: x=76, y=221
# Offset: x=-564, y=-139
# Red Cross Found at: x=172, y=225
# Offset: x=-468, y=-135
# Red Cross Found at: x=128, y=193
# Offset: x=-512, y=-167
# Red Cross Found at: x=1034, y=98
# Offset: x=394, y=-262
# Red Cross Found at: x=211, y=703
# Offset: x=-429, y=343
# Red Cross Found at: x=787, y=686
# Offset: x=147, y=326
# Red Cross Found at: x=26, y=597
# Offset: x=-614, y=237
# Red Cross Found at: x=1046, y=644
# Offset: x=406, y=284
# Red Cross Found at: x=952, y=510
# Offset: x=312, y=150
# Red Cross Found at: x=1152, y=330
# Offset: x=512, y=-30
# Red Cross Found at: x=966, y=241
# Offset: x=326, y=-119
# Red Cross Found at: x=66, y=394
# Offset: x=-574, y=34
# Red Cross Found at: x=28, y=244
# Offset: x=-612, y=-116
# Red Cross Found at: x=73, y=229
# Offset: x=-567, y=-131
# Red Cross Found at: x=178, y=218
# Offset: x=-462, y=-142
# Red Cross Found at: x=1033, y=97
# Offset: x=393, y=-263
# Red Cross Found at: x=212, y=699
# Offset: x=-428, y=339
# Red Cross Found at: x=858, y=593
# Offset: x=218, y=233
# Red Cross Found at: x=34, y=607
# Offset: x=-606, y=247
# Red Cross Found at: x=1042, y=641
# Offset: x=402, y=281
# Red Cross Found at: x=1165, y=320
# Offset: x=525, y=-40
# Red Cross Found at: x=965, y=238
# Offset: x=325, y=-122
# Red Cross Found at: x=176, y=221
# Offset: x=-464, y=-139
# Red Cross Found at: x=130, y=196
# Offset: x=-510, y=-164
# Red Cross Found at: x=206, y=699
# Offset: x=-434, y=339
# Red Cross Found at: x=34, y=629
# Offset: x=-606, y=269
# Red Cross Found at: x=1053, y=662
# Offset: x=413, y=302
# Red Cross Found at: x=961, y=500
# Offset: x=321, y=140
# Red Cross Found at: x=1253, y=275
# Offset: x=613, y=-85
# Red Cross Found at: x=1001, y=243
# Offset: x=361, y=-117
# Red Cross Found at: x=1180, y=253
# Offset: x=540, y=-107
# Red Cross Found at: x=532, y=215
# Offset: x=-108, y=-145
# Red Cross Found at: x=181, y=225
# Offset: x=-459, y=-135
# Red Cross Found at: x=128, y=197
# Offset: x=-512, y=-163
# Red Cross Found at: x=88, y=174
# Offset: x=-552, y=-186
# Red Cross Found at: x=1032, y=100
# Offset: x=392, y=-260
# Red Cross Found at: x=909, y=591
# Offset: x=269, y=231
# Red Cross Found at: x=608, y=584
# Offset: x=-32, y=224
# Red Cross Found at: x=651, y=590
# Offset: x=11, y=230
# Red Cross Found at: x=1041, y=647
# Offset: x=401, y=287
# Red Cross Found at: x=1194, y=280
# Offset: x=554, y=-80
# Red Cross Found at: x=988, y=245
# Offset: x=348, y=-115
# Red Cross Found at: x=1037, y=274
# Offset: x=397, y=-86
# Red Cross Found at: x=527, y=300
# Offset: x=-113, y=-60
# Red Cross Found at: x=261, y=289
# Offset: x=-379, y=-71
# Red Cross Found at: x=80, y=227
# Offset: x=-560, y=-133
# Red Cross Found at: x=130, y=198
# Offset: x=-510, y=-162
# Red Cross Found at: x=1039, y=97
# Offset: x=399, y=-263
# Red Cross Found at: x=53, y=638
# Offset: x=-587, y=278
# Red Cross Found at: x=1030, y=637
# Offset: x=390, y=277
# Red Cross Found at: x=1058, y=458
# Offset: x=418, y=98
# Red Cross Found at: x=1252, y=279
# Offset: x=612, y=-81
# Red Cross Found at: x=821, y=296
# Offset: x=181, y=-64
# Red Cross Found at: x=263, y=292
# Offset: x=-377, y=-68
# Red Cross Found at: x=95, y=311
# Offset: x=-545, y=-49
# Red Cross Found at: x=176, y=232
# Offset: x=-464, y=-128
# Red Cross Found at: x=132, y=197
# Offset: x=-508, y=-163
# Red Cross Found at: x=99, y=145
# Offset: x=-541, y=-215
# Red Cross Found at: x=1037, y=100
# Offset: x=397, y=-260
# Red Cross Found at: x=58, y=655
# Offset: x=-582, y=295
# Red Cross Found at: x=1040, y=658
# Offset: x=400, y=298
# Red Cross Found at: x=1059, y=463
# Offset: x=419, y=103
# Red Cross Found at: x=1252, y=365
# Offset: x=612, y=5
# Red Cross Found at: x=1085, y=293
# Offset: x=445, y=-67
# Red Cross Found at: x=118, y=271
# Offset: x=-522, y=-89
# Red Cross Found at: x=1038, y=101
# Offset: x=398, y=-259
# Red Cross Found at: x=810, y=669
# Offset: x=170, y=309
# Red Cross Found at: x=38, y=639
# Offset: x=-602, y=279
# Red Cross Found at: x=57, y=606
# Offset: x=-583, y=246
# Red Cross Found at: x=629, y=582
# Offset: x=-11, y=222
# Red Cross Found at: x=913, y=604
# Offset: x=273, y=244
# Red Cross Found at: x=1194, y=322
# Offset: x=554, y=-38
# Red Cross Found at: x=1256, y=145
# Offset: x=616, y=-215
# Red Cross Found at: x=1032, y=109
# Offset: x=392, y=-251
# Red Cross Found at: x=74, y=392
# Offset: x=-566, y=32
# Red Cross Found at: x=154, y=280
# Offset: x=-486, y=-80
# Red Cross Found at: x=854, y=258
# Offset: x=214, y=-102
# Red Cross Found at: x=80, y=241
# Offset: x=-560, y=-119
# Red Cross Found at: x=179, y=207
# Offset: x=-461, y=-153
# Red Cross Found at: x=67, y=183
# Offset: x=-573, y=-177
# Red Cross Found at: x=172, y=155
# Offset: x=-468, y=-205
# Red Cross Found at: x=853, y=655
# Offset: x=213, y=295
# Red Cross Found at: x=629, y=579
# Offset: x=-11, y=219
# Red Cross Found at: x=1044, y=694
# Offset: x=404, y=334
# Red Cross Found at: x=1114, y=325
# Offset: x=474, y=-35
# Red Cross Found at: x=1214, y=324
# Offset: x=574, y=-36
# Red Cross Found at: x=1228, y=244
# Offset: x=588, y=-116
# Red Cross Found at: x=94, y=347
# Offset: x=-546, y=-13
# Red Cross Found at: x=164, y=338
# Offset: x=-476, y=-22
# Red Cross Found at: x=210, y=345
# Offset: x=-430, y=-15
# Red Cross Found at: x=125, y=332
# Offset: x=-515, y=-28
# Red Cross Found at: x=267, y=286
# Offset: x=-373, y=-74
# Red Cross Found at: x=298, y=272
# Offset: x=-342, y=-88
# Red Cross Found at: x=102, y=293
# Offset: x=-538, y=-67
# Red Cross Found at: x=158, y=275
# Offset: x=-482, y=-85
# Red Cross Found at: x=93, y=220
# Offset: x=-547, y=-140
# Red Cross Found at: x=1202, y=209
# Offset: x=562, y=-151
# Red Cross Found at: x=50, y=552
# Offset: x=-590, y=192
# Red Cross Found at: x=66, y=389
# Offset: x=-574, y=29
# Red Cross Found at: x=26, y=316
# Offset: x=-614, y=-44
# Red Cross Found at: x=235, y=260
# Offset: x=-405, y=-100
# Red Cross Found at: x=171, y=296
# Offset: x=-469, y=-64
# Red Cross Found at: x=79, y=282
# Offset: x=-561, y=-78
# Red Cross Found at: x=193, y=199
# Offset: x=-447, y=-161
# Red Cross Found at: x=122, y=196
# Offset: x=-518, y=-164
# Red Cross Found at: x=212, y=699
# Offset: x=-428, y=339
# Red Cross Found at: x=30, y=679
# Offset: x=-610, y=319
# Red Cross Found at: x=629, y=583
# Offset: x=-11, y=223
# Red Cross Found at: x=42, y=577
# Offset: x=-598, y=217
# Red Cross Found at: x=45, y=564
# Offset: x=-595, y=204
# Red Cross Found at: x=1026, y=548
# Offset: x=386, y=188
# Red Cross Found at: x=1244, y=347
# Offset: x=604, y=-13
# Red Cross Found at: x=1170, y=294
# Offset: x=530, y=-66
# Red Cross Found at: x=1189, y=190
# Offset: x=549, y=-170
# Red Cross Found at: x=1240, y=194
# Offset: x=600, y=-166
# Red Cross Found at: x=1250, y=147
# Offset: x=610, y=-213
# Red Cross Found at: x=62, y=14
# Offset: x=-578, y=-346
# Red Cross Found at: x=64, y=396
# Offset: x=-576, y=36
# Red Cross Found at: x=233, y=330
# Offset: x=-407, y=-30
# Red Cross Found at: x=202, y=333
# Offset: x=-438, y=-27
# Red Cross Found at: x=127, y=328
# Offset: x=-513, y=-32
# Red Cross Found at: x=102, y=300
# Offset: x=-538, y=-60
# Red Cross Found at: x=154, y=275
# Offset: x=-486, y=-85
# Red Cross Found at: x=74, y=242
# Offset: x=-566, y=-118
# Red Cross Found at: x=119, y=198
# Offset: x=-521, y=-162
# Red Cross Found at: x=271, y=198
# Offset: x=-369, y=-162
# Red Cross Found at: x=90, y=182
# Offset: x=-550, y=-178
# Red Cross Found at: x=212, y=700
# Offset: x=-428, y=340
# Red Cross Found at: x=32, y=682
# Offset: x=-608, y=322
# Red Cross Found at: x=630, y=583
# Offset: x=-10, y=223
# Red Cross Found at: x=994, y=547
# Offset: x=354, y=187
# Red Cross Found at: x=1239, y=333
# Offset: x=599, y=-27
# Red Cross Found at: x=1171, y=284
# Offset: x=531, y=-76
# Red Cross Found at: x=1256, y=193
# Offset: x=616, y=-167
# Red Cross Found at: x=1174, y=172
# Offset: x=534, y=-188
# Red Cross Found at: x=63, y=385
# Offset: x=-577, y=25
# Red Cross Found at: x=120, y=336
# Offset: x=-520, y=-24
# Red Cross Found at: x=100, y=300
# Offset: x=-540, y=-60
# Red Cross Found at: x=853, y=266
# Offset: x=213, y=-94
# Red Cross Found at: x=179, y=293
# Offset: x=-461, y=-67
# Red Cross Found at: x=129, y=203
# Offset: x=-511, y=-157
# Red Cross Found at: x=271, y=197
# Offset: x=-369, y=-163
# Red Cross Found at: x=86, y=204
# Offset: x=-554, y=-156
# Red Cross Found at: x=1014, y=167
# Offset: x=374, y=-193
# Red Cross Found at: x=213, y=699
# Offset: x=-427, y=339
# Red Cross Found at: x=31, y=680
# Offset: x=-609, y=320
# Red Cross Found at: x=634, y=585
# Offset: x=-6, y=225
# Red Cross Found at: x=1026, y=549
# Offset: x=386, y=189
# Red Cross Found at: x=1250, y=387
# Offset: x=610, y=27
# Red Cross Found at: x=1175, y=354
# Offset: x=535, y=-6
# Red Cross Found at: x=1131, y=306
# Offset: x=491, y=-54
# Red Cross Found at: x=1189, y=277
# Offset: x=549, y=-83
# Red Cross Found at: x=1248, y=203
# Offset: x=608, y=-157
# Red Cross Found at: x=63, y=14
# Offset: x=-577, y=-346
# Red Cross Found at: x=214, y=335
# Offset: x=-426, y=-25
# Red Cross Found at: x=94, y=309
# Offset: x=-546, y=-51
# Red Cross Found at: x=72, y=268
# Offset: x=-568, y=-92
# Red Cross Found at: x=103, y=267
# Offset: x=-537, y=-93
# Red Cross Found at: x=853, y=270
# Offset: x=213, y=-90
# Red Cross Found at: x=126, y=191
# Offset: x=-514, y=-169
# Red Cross Found at: x=444, y=178
# Offset: x=-196, y=-182
# Red Cross Found at: x=212, y=698
# Offset: x=-428, y=338
# Red Cross Found at: x=33, y=679
# Offset: x=-607, y=319
# Red Cross Found at: x=800, y=615
# Offset: x=160, y=255
# Red Cross Found at: x=634, y=584
# Offset: x=-6, y=224
# Red Cross Found at: x=1017, y=541
# Offset: x=377, y=181
# Red Cross Found at: x=1026, y=639
# Offset: x=386, y=279
# Red Cross Found at: x=1249, y=284
# Offset: x=609, y=-76
# Red Cross Found at: x=1192, y=316
# Offset: x=552, y=-44
# Red Cross Found at: x=1191, y=343
# Offset: x=551, y=-17
# Red Cross Found at: x=1161, y=295
# Offset: x=521, y=-65
# Red Cross Found at: x=1257, y=195
# Offset: x=617, y=-165
# Red Cross Found at: x=66, y=390
# Offset: x=-574, y=30
# Red Cross Found at: x=219, y=334
# Offset: x=-421, y=-26
# Red Cross Found at: x=101, y=281
# Offset: x=-539, y=-79
# Red Cross Found at: x=851, y=262
# Offset: x=211, y=-98
# Red Cross Found at: x=127, y=193
# Offset: x=-513, y=-167
# Red Cross Found at: x=908, y=180
# Offset: x=268, y=-180
# Red Cross Found at: x=85, y=175
# Offset: x=-555, y=-185
# Red Cross Found at: x=203, y=699
# Offset: x=-437, y=339
# Red Cross Found at: x=30, y=680
# Offset: x=-610, y=320
# Red Cross Found at: x=801, y=615
# Offset: x=161, y=255
# Red Cross Found at: x=1010, y=548
# Offset: x=370, y=188
# Red Cross Found at: x=1026, y=637
# Offset: x=386, y=277
# Red Cross Found at: x=1245, y=394
# Offset: x=605, y=34
# Red Cross Found at: x=1257, y=280
# Offset: x=617, y=-80
# Red Cross Found at: x=74, y=379
# Offset: x=-566, y=19
# Red Cross Found at: x=164, y=311
# Offset: x=-476, y=-49
# Red Cross Found at: x=232, y=299
# Offset: x=-408, y=-61
# Red Cross Found at: x=853, y=263
# Offset: x=213, y=-97
# Red Cross Found at: x=148, y=249
# Offset: x=-492, y=-111
# Red Cross Found at: x=330, y=154
# Offset: x=-310, y=-206
# Red Cross Found at: x=62, y=26
# Offset: x=-578, y=-334
# Red Cross Found at: x=205, y=698
# Offset: x=-435, y=338
# Red Cross Found at: x=47, y=679
# Offset: x=-593, y=319
# Red Cross Found at: x=802, y=611
# Offset: x=162, y=251
# Red Cross Found at: x=990, y=547
# Offset: x=350, y=187
# Red Cross Found at: x=1026, y=636
# Offset: x=386, y=276
# Red Cross Found at: x=910, y=391
# Offset: x=270, y=31
# Red Cross Found at: x=1252, y=286
# Offset: x=612, y=-74
# Red Cross Found at: x=1247, y=202
# Offset: x=607, y=-158
# Red Cross Found at: x=204, y=338
# Offset: x=-436, y=-22
# Red Cross Found at: x=82, y=276
# Offset: x=-558, y=-84
# Red Cross Found at: x=852, y=261
# Offset: x=212, y=-99
# Red Cross Found at: x=246, y=292
# Offset: x=-394, y=-68
# Red Cross Found at: x=71, y=234
# Offset: x=-569, y=-126
# Red Cross Found at: x=1018, y=207
# Offset: x=378, y=-153
# Red Cross Found at: x=135, y=234
# Offset: x=-505, y=-126
# Red Cross Found at: x=323, y=151
# Offset: x=-317, y=-209
# Red Cross Found at: x=42, y=680
# Offset: x=-598, y=320
# Red Cross Found at: x=1027, y=632
# Offset: x=387, y=272
# Red Cross Found at: x=924, y=369
# Offset: x=284, y=9
# Red Cross Found at: x=1252, y=281
# Offset: x=612, y=-79
# Red Cross Found at: x=1175, y=302
# Offset: x=535, y=-58
# Red Cross Found at: x=1254, y=201
# Offset: x=614, y=-159
# Red Cross Found at: x=170, y=308
# Offset: x=-470, y=-52
# Red Cross Found at: x=255, y=265
# Offset: x=-385, y=-95
# Red Cross Found at: x=139, y=258
# Offset: x=-501, y=-102
# Red Cross Found at: x=84, y=274
# Offset: x=-556, y=-86
# Red Cross Found at: x=97, y=226
# Offset: x=-543, y=-134
# Red Cross Found at: x=129, y=191
# Offset: x=-511, y=-169
# Red Cross Found at: x=339, y=160
# Offset: x=-301, y=-200
# Red Cross Found at: x=66, y=16
# Offset: x=-574, y=-344
# Red Cross Found at: x=34, y=679
# Offset: x=-606, y=319
# Red Cross Found at: x=850, y=651
# Offset: x=210, y=291
# Red Cross Found at: x=1048, y=689
# Offset: x=408, y=329
# Red Cross Found at: x=1019, y=634
# Offset: x=379, y=274
# Red Cross Found at: x=1249, y=399
# Offset: x=609, y=39
# Red Cross Found at: x=1085, y=288
# Offset: x=445, y=-72
# Red Cross Found at: x=1256, y=284
# Offset: x=616, y=-76
# Red Cross Found at: x=1168, y=300
# Offset: x=528, y=-60
# Red Cross Found at: x=66, y=397
# Offset: x=-574, y=37
# Red Cross Found at: x=164, y=305
# Offset: x=-476, y=-55
# Red Cross Found at: x=27, y=256
# Offset: x=-613, y=-104
# Red Cross Found at: x=263, y=263
# Offset: x=-377, y=-97
# Red Cross Found at: x=270, y=187
# Offset: x=-370, y=-173
# Red Cross Found at: x=67, y=18
# Offset: x=-573, y=-342
# Red Cross Found at: x=206, y=700
# Offset: x=-434, y=340
# Red Cross Found at: x=611, y=577
# Offset: x=-29, y=217
# Red Cross Found at: x=951, y=612
# Offset: x=311, y=252
# Red Cross Found at: x=1232, y=375
# Offset: x=592, y=15
# Red Cross Found at: x=1249, y=383
# Offset: x=609, y=23
# Red Cross Found at: x=1094, y=290
# Offset: x=454, y=-70
# Red Cross Found at: x=1167, y=305
# Offset: x=527, y=-55
# Red Cross Found at: x=1189, y=299
# Offset: x=549, y=-61
# Red Cross Found at: x=37, y=646
# Offset: x=-603, y=286
# Red Cross Found at: x=68, y=389
# Offset: x=-572, y=29
# Red Cross Found at: x=172, y=308
# Offset: x=-468, y=-52
# Red Cross Found at: x=32, y=258
# Offset: x=-608, y=-102
# Red Cross Found at: x=1040, y=268
# Offset: x=400, y=-92
# Red Cross Found at: x=261, y=252
# Offset: x=-379, y=-108
# Red Cross Found at: x=104, y=247
# Offset: x=-536, y=-113
# Red Cross Found at: x=622, y=578
# Offset: x=-18, y=218
# Red Cross Found at: x=948, y=614
# Offset: x=308, y=254
# Red Cross Found at: x=1252, y=381
# Offset: x=612, y=21
# Red Cross Found at: x=1097, y=283
# Offset: x=457, y=-77
# Red Cross Found at: x=1195, y=263
# Offset: x=555, y=-97
# Red Cross Found at: x=28, y=578
# Offset: x=-612, y=218
# Red Cross Found at: x=67, y=387
# Offset: x=-573, y=27
# Red Cross Found at: x=126, y=346
# Offset: x=-514, y=-14
# Red Cross Found at: x=51, y=347
# Offset: x=-589, y=-13
# Red Cross Found at: x=254, y=270
# Offset: x=-386, y=-90
# Red Cross Found at: x=134, y=259
# Offset: x=-506, y=-101
# Red Cross Found at: x=336, y=161
# Offset: x=-304, y=-199
# Red Cross Found at: x=230, y=162
# Offset: x=-410, y=-198
# Red Cross Found at: x=61, y=16
# Offset: x=-579, y=-344
# Red Cross Found at: x=851, y=653
# Offset: x=211, y=293
# Red Cross Found at: x=793, y=609
# Offset: x=153, y=249
# Red Cross Found at: x=1002, y=575
# Offset: x=362, y=215
# Red Cross Found at: x=944, y=610
# Offset: x=304, y=250
# Red Cross Found at: x=1041, y=396
# Offset: x=401, y=36
# Red Cross Found at: x=1248, y=375
# Offset: x=608, y=15
# Red Cross Found at: x=1264, y=175
# Offset: x=624, y=-185
# Red Cross Found at: x=32, y=611
# Offset: x=-608, y=251
# Red Cross Found at: x=49, y=362
# Offset: x=-591, y=2
# Red Cross Found at: x=147, y=289
# Offset: x=-493, y=-71
# Red Cross Found at: x=1124, y=264
# Offset: x=484, y=-96
# Red Cross Found at: x=61, y=17
# Offset: x=-579, y=-343
# Red Cross Found at: x=207, y=693
# Offset: x=-433, y=333
# Red Cross Found at: x=828, y=662
# Offset: x=188, y=302
# Red Cross Found at: x=616, y=576
# Offset: x=-24, y=216
# Red Cross Found at: x=1048, y=692
# Offset: x=408, y=332
# Red Cross Found at: x=889, y=411
# Offset: x=249, y=51
# Red Cross Found at: x=1042, y=401
# Offset: x=402, y=41
# Red Cross Found at: x=942, y=363
# Offset: x=302, y=3
# Red Cross Found at: x=1190, y=343
# Offset: x=550, y=-17
# Red Cross Found at: x=1173, y=319
# Offset: x=533, y=-41
# Red Cross Found at: x=1229, y=179
# Offset: x=589, y=-181
# Red Cross Found at: x=40, y=629
# Offset: x=-600, y=269
# Red Cross Found at: x=68, y=352
# Offset: x=-572, y=-8
# Red Cross Found at: x=169, y=307
# Offset: x=-471, y=-53
# Red Cross Found at: x=108, y=299
# Offset: x=-532, y=-61
# Red Cross Found at: x=31, y=280
# Offset: x=-609, y=-80
# Red Cross Found at: x=70, y=280
# Offset: x=-570, y=-80
# Red Cross Found at: x=115, y=256
# Offset: x=-525, y=-104
# Red Cross Found at: x=264, y=250
# Offset: x=-376, y=-110
# Red Cross Found at: x=137, y=213
# Offset: x=-503, y=-147
# Red Cross Found at: x=268, y=179
# Offset: x=-372, y=-181
# Red Cross Found at: x=341, y=159
# Offset: x=-299, y=-201
# Red Cross Found at: x=111, y=143
# Offset: x=-529, y=-217
# Red Cross Found at: x=64, y=14
# Offset: x=-576, y=-346
# Red Cross Found at: x=208, y=697
# Offset: x=-432, y=337
# Red Cross Found at: x=796, y=614
# Offset: x=156, y=254
# Red Cross Found at: x=634, y=577
# Offset: x=-6, y=217
# Red Cross Found at: x=1047, y=694
# Offset: x=407, y=334
# Red Cross Found at: x=1019, y=633
# Offset: x=379, y=273
# Red Cross Found at: x=1156, y=314
# Offset: x=516, y=-46
# Red Cross Found at: x=857, y=409
# Offset: x=217, y=49
# Red Cross Found at: x=45, y=375
# Offset: x=-595, y=15
# Red Cross Found at: x=131, y=349
# Offset: x=-509, y=-11
# Red Cross Found at: x=71, y=347
# Offset: x=-569, y=-13
# Red Cross Found at: x=178, y=308
# Offset: x=-462, y=-52
# Red Cross Found at: x=23, y=294
# Offset: x=-617, y=-66
# Red Cross Found at: x=297, y=274
# Offset: x=-343, y=-86
# Red Cross Found at: x=264, y=253
# Offset: x=-376, y=-107
# Red Cross Found at: x=86, y=175
# Offset: x=-554, y=-185
# Red Cross Found at: x=148, y=230
# Offset: x=-492, y=-130
# Red Cross Found at: x=272, y=166
# Offset: x=-368, y=-194
# Red Cross Found at: x=925, y=151
# Offset: x=285, y=-209
# Red Cross Found at: x=63, y=14
# Offset: x=-577, y=-346
# Red Cross Found at: x=209, y=696
# Offset: x=-431, y=336
# Red Cross Found at: x=807, y=615
# Offset: x=167, y=255
# Red Cross Found at: x=1008, y=566
# Offset: x=368, y=206
# Red Cross Found at: x=885, y=416
# Offset: x=245, y=56
# Red Cross Found at: x=1096, y=282
# Offset: x=456, y=-78
# Red Cross Found at: x=1164, y=249
# Offset: x=524, y=-111
# Red Cross Found at: x=1193, y=327
# Offset: x=553, y=-33
# Red Cross Found at: x=266, y=271
# Offset: x=-374, y=-89
# Red Cross Found at: x=91, y=302
# Offset: x=-549, y=-58
# Red Cross Found at: x=157, y=279
# Offset: x=-483, y=-81
# Red Cross Found at: x=131, y=201
# Offset: x=-509, y=-159
# Red Cross Found at: x=243, y=181
# Offset: x=-397, y=-179
# Red Cross Found at: x=928, y=152
# Offset: x=288, y=-208
# Red Cross Found at: x=63, y=14
# Offset: x=-577, y=-346
# Red Cross Found at: x=209, y=695
# Offset: x=-431, y=335
# Red Cross Found at: x=825, y=683
# Offset: x=185, y=323
# Red Cross Found at: x=1002, y=569
# Offset: x=362, y=209
# Red Cross Found at: x=930, y=600
# Offset: x=290, y=240
# Red Cross Found at: x=1133, y=220
# Offset: x=493, y=-140
# Red Cross Found at: x=1238, y=399
# Offset: x=598, y=39
# Red Cross Found at: x=178, y=317
# Offset: x=-462, y=-43
# Red Cross Found at: x=261, y=269
# Offset: x=-379, y=-91
# Red Cross Found at: x=97, y=299
# Offset: x=-543, y=-61
# Red Cross Found at: x=1092, y=277
# Offset: x=452, y=-83
# Red Cross Found at: x=152, y=272
# Offset: x=-488, y=-88
# Red Cross Found at: x=171, y=199
# Offset: x=-469, y=-161
# Red Cross Found at: x=240, y=189
# Offset: x=-400, y=-171
# Red Cross Found at: x=846, y=591
# Offset: x=206, y=231
# Red Cross Found at: x=930, y=602
# Offset: x=290, y=242
# Red Cross Found at: x=1224, y=182
# Offset: x=584, y=-178
# Red Cross Found at: x=1242, y=389
# Offset: x=602, y=29
# Red Cross Found at: x=185, y=320
# Offset: x=-455, y=-40
# Red Cross Found at: x=1156, y=288
# Offset: x=516, y=-72
# Red Cross Found at: x=199, y=270
# Offset: x=-441, y=-90
# Red Cross Found at: x=28, y=282
# Offset: x=-612, y=-78
# Red Cross Found at: x=1079, y=262
# Offset: x=439, y=-98
# Red Cross Found at: x=116, y=297
# Offset: x=-524, y=-63
# Red Cross Found at: x=1136, y=255
# Offset: x=496, y=-105
# Red Cross Found at: x=1106, y=235
# Offset: x=466, y=-125
# Red Cross Found at: x=1200, y=212
# Offset: x=560, y=-148
# Red Cross Found at: x=103, y=167
# Offset: x=-537, y=-193
# Red Cross Found at: x=998, y=162
# Offset: x=358, y=-198
# Red Cross Found at: x=68, y=16
# Offset: x=-572, y=-344
# Red Cross Found at: x=209, y=697
# Offset: x=-431, y=337
# Red Cross Found at: x=1025, y=540
# Offset: x=385, y=180
# Red Cross Found at: x=1021, y=631
# Offset: x=381, y=271
# Red Cross Found at: x=931, y=600
# Offset: x=291, y=240
# Red Cross Found at: x=1225, y=179
# Offset: x=585, y=-181
# Red Cross Found at: x=180, y=316
# Offset: x=-460, y=-44
# Red Cross Found at: x=24, y=296
# Offset: x=-616, y=-64
# Red Cross Found at: x=95, y=299
# Offset: x=-545, y=-61
# Red Cross Found at: x=148, y=264
# Offset: x=-492, y=-96
# Red Cross Found at: x=296, y=246
# Offset: x=-344, y=-114
# Red Cross Found at: x=132, y=188
# Offset: x=-508, y=-172
# Red Cross Found at: x=170, y=157
# Offset: x=-470, y=-203
# Red Cross Found at: x=1003, y=547
# Offset: x=363, y=187
# Red Cross Found at: x=927, y=624
# Offset: x=287, y=264
# Red Cross Found at: x=852, y=596
# Offset: x=212, y=236
# Red Cross Found at: x=91, y=333
# Offset: x=-549, y=-27
# Red Cross Found at: x=177, y=318
# Offset: x=-463, y=-42
# Red Cross Found at: x=200, y=258
# Offset: x=-440, y=-102
# Red Cross Found at: x=297, y=261
# Offset: x=-343, y=-99
# Red Cross Found at: x=42, y=255
# Offset: x=-598, y=-105
# Red Cross Found at: x=262, y=260
# Offset: x=-378, y=-100
# Red Cross Found at: x=122, y=274
# Offset: x=-518, y=-86
# Red Cross Found at: x=107, y=223
# Offset: x=-533, y=-137
# Red Cross Found at: x=45, y=197
# Offset: x=-595, y=-163
# Red Cross Found at: x=239, y=201
# Offset: x=-401, y=-159
# Red Cross Found at: x=137, y=184
# Offset: x=-503, y=-176
# Red Cross Found at: x=1114, y=179
# Offset: x=474, y=-181
# Red Cross Found at: x=108, y=172
# Offset: x=-532, y=-188
# Red Cross Found at: x=1006, y=160
# Offset: x=366, y=-200
# Red Cross Found at: x=25, y=61
# Offset: x=-615, y=-299
# Red Cross Found at: x=65, y=21
# Offset: x=-575, y=-339
# Red Cross Found at: x=206, y=695
# Offset: x=-434, y=335
# Red Cross Found at: x=834, y=632
# Offset: x=194, y=272
# Red Cross Found at: x=852, y=600
# Offset: x=212, y=240
# Red Cross Found at: x=1108, y=575
# Offset: x=468, y=215
# Red Cross Found at: x=1085, y=479
# Offset: x=445, y=119
# Red Cross Found at: x=1201, y=180
# Offset: x=561, y=-180
# Red Cross Found at: x=1248, y=167
# Offset: x=608, y=-193
# Red Cross Found at: x=69, y=359
# Offset: x=-571, y=-1
# Red Cross Found at: x=260, y=269
# Offset: x=-380, y=-91
# Red Cross Found at: x=298, y=260
# Offset: x=-342, y=-100
# Red Cross Found at: x=147, y=261
# Offset: x=-493, y=-99
# Red Cross Found at: x=105, y=260
# Offset: x=-535, y=-100
# Red Cross Found at: x=84, y=210
# Offset: x=-556, y=-150
# Red Cross Found at: x=224, y=193
# Offset: x=-416, y=-167
# Red Cross Found at: x=136, y=185
# Offset: x=-504, y=-175
# Red Cross Found at: x=242, y=164
# Offset: x=-398, y=-196
# Red Cross Found at: x=25, y=48
# Offset: x=-615, y=-312
# Red Cross Found at: x=64, y=20
# Offset: x=-576, y=-340
# Red Cross Found at: x=803, y=637
# Offset: x=163, y=277
# Red Cross Found at: x=1022, y=569
# Offset: x=382, y=209
# Red Cross Found at: x=971, y=616
# Offset: x=331, y=256
# Red Cross Found at: x=81, y=365
# Offset: x=-559, y=5
# Red Cross Found at: x=81, y=266
# Offset: x=-559, y=-94
# Red Cross Found at: x=260, y=266
# Offset: x=-380, y=-94
# Red Cross Found at: x=293, y=257
# Offset: x=-347, y=-103
# Red Cross Found at: x=145, y=261
# Offset: x=-495, y=-99
# Red Cross Found at: x=231, y=198
# Offset: x=-409, y=-162
# Red Cross Found at: x=78, y=204
# Offset: x=-562, y=-156
# Red Cross Found at: x=137, y=184
# Offset: x=-503, y=-176
# Red Cross Found at: x=65, y=19
# Offset: x=-575, y=-341
# Red Cross Found at: x=205, y=695
# Offset: x=-435, y=335
# Red Cross Found at: x=805, y=642
# Offset: x=165, y=282
# Red Cross Found at: x=642, y=580
# Offset: x=2, y=220
# Red Cross Found at: x=1018, y=573
# Offset: x=378, y=213
# Red Cross Found at: x=910, y=389
# Offset: x=270, y=29
# Red Cross Found at: x=1173, y=185
# Offset: x=533, y=-175
# Red Cross Found at: x=1242, y=164
# Offset: x=602, y=-196
# Red Cross Found at: x=60, y=380
# Offset: x=-580, y=20
# Red Cross Found at: x=82, y=341
# Offset: x=-558, y=-19
# Red Cross Found at: x=1171, y=321
# Offset: x=531, y=-39
# Red Cross Found at: x=96, y=275
# Offset: x=-544, y=-85
# Red Cross Found at: x=1084, y=259
# Offset: x=444, y=-101
# Red Cross Found at: x=135, y=185
# Offset: x=-505, y=-175
# Red Cross Found at: x=1085, y=163
# Offset: x=445, y=-197
# Red Cross Found at: x=224, y=163
# Offset: x=-416, y=-197
# Red Cross Found at: x=203, y=698
# Offset: x=-437, y=338
# Red Cross Found at: x=810, y=633
# Offset: x=170, y=273
# Red Cross Found at: x=863, y=570
# Offset: x=223, y=210
# Red Cross Found at: x=872, y=440
# Offset: x=232, y=80
# Red Cross Found at: x=913, y=383
# Offset: x=273, y=23
# Red Cross Found at: x=1027, y=540
# Offset: x=387, y=180
# Red Cross Found at: x=1192, y=314
# Offset: x=552, y=-46
# Red Cross Found at: x=1183, y=179
# Offset: x=543, y=-181
# Red Cross Found at: x=1251, y=169
# Offset: x=611, y=-191
# Red Cross Found at: x=45, y=612
# Offset: x=-595, y=252
# Red Cross Found at: x=56, y=380
# Offset: x=-584, y=20
# Red Cross Found at: x=111, y=357
# Offset: x=-529, y=-3
# Red Cross Found at: x=97, y=276
# Offset: x=-543, y=-84
# Red Cross Found at: x=1074, y=263
# Offset: x=434, y=-97
# Red Cross Found at: x=122, y=233
# Offset: x=-518, y=-127
# Red Cross Found at: x=50, y=201
# Offset: x=-590, y=-159
# Red Cross Found at: x=224, y=181
# Offset: x=-416, y=-179
# Red Cross Found at: x=67, y=19
# Offset: x=-573, y=-341
# Red Cross Found at: x=207, y=695
# Offset: x=-433, y=335
# Red Cross Found at: x=628, y=579
# Offset: x=-12, y=219
# Red Cross Found at: x=989, y=542
# Offset: x=349, y=182
# Red Cross Found at: x=869, y=672
# Offset: x=229, y=312
# Red Cross Found at: x=1105, y=576
# Offset: x=465, y=216
# Red Cross Found at: x=915, y=392
# Offset: x=275, y=32
# Red Cross Found at: x=43, y=591
# Offset: x=-597, y=231
# Red Cross Found at: x=62, y=380
# Offset: x=-578, y=20
# Red Cross Found at: x=1174, y=283
# Offset: x=534, y=-77
# Red Cross Found at: x=33, y=259
# Offset: x=-607, y=-101
# Red Cross Found at: x=118, y=257
# Offset: x=-522, y=-103
# Red Cross Found at: x=39, y=219
# Offset: x=-601, y=-141
# Red Cross Found at: x=205, y=693
# Offset: x=-435, y=333
# Red Cross Found at: x=817, y=618
# Offset: x=177, y=258
# Red Cross Found at: x=622, y=584
# Offset: x=-18, y=224
# Red Cross Found at: x=1028, y=545
# Offset: x=388, y=185
# Red Cross Found at: x=1032, y=637
# Offset: x=392, y=277
# Red Cross Found at: x=914, y=391
# Offset: x=274, y=31
# Red Cross Found at: x=68, y=385
# Offset: x=-572, y=25
# Red Cross Found at: x=62, y=301
# Offset: x=-578, y=-59
# Red Cross Found at: x=1173, y=279
# Offset: x=533, y=-81
# Red Cross Found at: x=1091, y=275
# Offset: x=451, y=-85
# Red Cross Found at: x=1110, y=233
# Offset: x=470, y=-127
# Red Cross Found at: x=103, y=263
# Offset: x=-537, y=-97
# Red Cross Found at: x=59, y=21
# Offset: x=-581, y=-339
# Red Cross Found at: x=208, y=696
# Offset: x=-432, y=336
# Red Cross Found at: x=861, y=633
# Offset: x=221, y=273
# Red Cross Found at: x=797, y=629
# Offset: x=157, y=269
# Red Cross Found at: x=1021, y=542
# Offset: x=381, y=182
# Red Cross Found at: x=1022, y=639
# Offset: x=382, y=279
# Red Cross Found at: x=62, y=15
# Offset: x=-578, y=-345
# Red Cross Found at: x=67, y=301
# Offset: x=-573, y=-59
# Red Cross Found at: x=1236, y=313
# Offset: x=596, y=-47
# Red Cross Found at: x=139, y=269
# Offset: x=-501, y=-91
# Red Cross Found at: x=85, y=282
# Offset: x=-555, y=-78
# Red Cross Found at: x=1100, y=255
# Offset: x=460, y=-105
# Red Cross Found at: x=1048, y=252
# Offset: x=408, y=-108
# Red Cross Found at: x=122, y=224
# Offset: x=-518, y=-136
# Red Cross Found at: x=792, y=702
# Offset: x=152, y=342
# Red Cross Found at: x=207, y=697
# Offset: x=-433, y=337
# Red Cross Found at: x=857, y=649
# Offset: x=217, y=289
# Red Cross Found at: x=645, y=585
# Offset: x=5, y=225
# Red Cross Found at: x=1008, y=538
# Offset: x=368, y=178
# Red Cross Found at: x=849, y=592
# Offset: x=209, y=232
# Red Cross Found at: x=1105, y=579
# Offset: x=465, y=219
# Red Cross Found at: x=1184, y=274
# Offset: x=544, y=-86
# Red Cross Found at: x=261, y=239
# Offset: x=-379, y=-121
# Red Cross Found at: x=1105, y=231
# Offset: x=465, y=-129
# Red Cross Found at: x=99, y=264
# Offset: x=-541, y=-96
# Red Cross Found at: x=332, y=150
# Offset: x=-308, y=-210
# Red Cross Found at: x=113, y=130
# Offset: x=-527, y=-230
# Red Cross Found at: x=206, y=698
# Offset: x=-434, y=338
# Red Cross Found at: x=641, y=580
# Offset: x=1, y=220
# Red Cross Found at: x=1002, y=547
# Offset: x=362, y=187
# Red Cross Found at: x=1025, y=632
# Offset: x=385, y=272
# Red Cross Found at: x=967, y=622
# Offset: x=327, y=262
# Red Cross Found at: x=1106, y=579
# Offset: x=466, y=219
# Red Cross Found at: x=929, y=371
# Offset: x=289, y=11
# Red Cross Found at: x=1104, y=291
# Offset: x=464, y=-69
# Red Cross Found at: x=1111, y=253
# Offset: x=471, y=-107
# Red Cross Found at: x=111, y=238
# Offset: x=-529, y=-122
# Red Cross Found at: x=64, y=14
# Offset: x=-576, y=-346
# Red Cross Found at: x=207, y=697
# Offset: x=-433, y=337
# Red Cross Found at: x=797, y=623
# Offset: x=157, y=263
# Red Cross Found at: x=971, y=631
# Offset: x=331, y=271
# Red Cross Found at: x=1022, y=630
# Offset: x=382, y=270
# Red Cross Found at: x=1234, y=310
# Offset: x=594, y=-50
# Red Cross Found at: x=91, y=285
# Offset: x=-549, y=-75
# Red Cross Found at: x=139, y=239
# Offset: x=-501, y=-121
# Red Cross Found at: x=65, y=13
# Offset: x=-575, y=-347
# Red Cross Found at: x=209, y=698
# Offset: x=-431, y=338
# Red Cross Found at: x=615, y=577
# Offset: x=-25, y=217
# Red Cross Found at: x=1022, y=632
# Offset: x=382, y=272
# Red Cross Found at: x=124, y=232
# Offset: x=-516, y=-128
# Red Cross Found at: x=1174, y=255
# Offset: x=534, y=-105
# Red Cross Found at: x=65, y=155
# Offset: x=-575, y=-205
# Red Cross Found at: x=66, y=14
# Offset: x=-574, y=-346
# Red Cross Found at: x=206, y=698
# Offset: x=-434, y=338
# Red Cross Found at: x=1016, y=541
# Offset: x=376, y=181
# Red Cross Found at: x=1107, y=576
# Offset: x=467, y=216
# Red Cross Found at: x=1186, y=331
# Offset: x=546, y=-29
# Red Cross Found at: x=1232, y=314
# Offset: x=592, y=-46
# Red Cross Found at: x=1108, y=230
# Offset: x=468, y=-130
# Red Cross Found at: x=126, y=234
# Offset: x=-514, y=-126
# Red Cross Found at: x=1135, y=190
# Offset: x=495, y=-170
# Red Cross Found at: x=106, y=177
# Offset: x=-534, y=-183
# Red Cross Found at: x=270, y=161
# Offset: x=-370, y=-199
# Red Cross Found at: x=65, y=14
# Offset: x=-575, y=-346
# Red Cross Found at: x=207, y=698
# Offset: x=-433, y=338
# Red Cross Found at: x=784, y=619
# Offset: x=144, y=259
# Red Cross Found at: x=617, y=576
# Offset: x=-23, y=216
# Red Cross Found at: x=1020, y=550
# Offset: x=380, y=190
# Red Cross Found at: x=1107, y=574
# Offset: x=467, y=214
# Red Cross Found at: x=1245, y=318
# Offset: x=605, y=-42
# Red Cross Found at: x=139, y=247
# Offset: x=-501, y=-113
# Red Cross Found at: x=270, y=160
# Offset: x=-370, y=-200
# Red Cross Found at: x=219, y=161
# Offset: x=-421, y=-199
# Red Cross Found at: x=379, y=156
# Offset: x=-261, y=-204
# Red Cross Found at: x=115, y=185
# Offset: x=-525, y=-175
# Red Cross Found at: x=67, y=159
# Offset: x=-573, y=-201
# Red Cross Found at: x=22, y=63
# Offset: x=-618, y=-297
# Red Cross Found at: x=64, y=25
# Offset: x=-576, y=-335
# Red Cross Found at: x=206, y=698
# Offset: x=-434, y=338
# Red Cross Found at: x=810, y=649
# Offset: x=170, y=289
# Red Cross Found at: x=993, y=553
# Offset: x=353, y=193
# Red Cross Found at: x=957, y=607
# Offset: x=317, y=247
# Red Cross Found at: x=25, y=682
# Offset: x=-615, y=322
# Red Cross Found at: x=82, y=288
# Offset: x=-558, y=-72
# Red Cross Found at: x=224, y=244
# Offset: x=-416, y=-116
# Red Cross Found at: x=61, y=174
# Offset: x=-579, y=-186
# Red Cross Found at: x=266, y=162
# Offset: x=-374, y=-198
# Red Cross Found at: x=164, y=154
# Offset: x=-476, y=-206
# Red Cross Found at: x=76, y=24
# Offset: x=-564, y=-336
# Red Cross Found at: x=210, y=694
# Offset: x=-430, y=334
# Red Cross Found at: x=27, y=691
# Offset: x=-613, y=331
# Red Cross Found at: x=615, y=573
# Offset: x=-25, y=213
# Red Cross Found at: x=984, y=550
# Offset: x=344, y=190
# Red Cross Found at: x=63, y=341
# Offset: x=-577, y=-19
# Red Cross Found at: x=83, y=290
# Offset: x=-557, y=-70
# Red Cross Found at: x=137, y=238
# Offset: x=-503, y=-122
# Red Cross Found at: x=85, y=210
# Offset: x=-555, y=-150
# Red Cross Found at: x=1202, y=272
# Offset: x=562, y=-88
# Red Cross Found at: x=1090, y=190
# Offset: x=450, y=-170
# Red Cross Found at: x=118, y=177
# Offset: x=-522, y=-183
# Red Cross Found at: x=227, y=161
# Offset: x=-413, y=-199
# Red Cross Found at: x=58, y=170
# Offset: x=-582, y=-190
# Red Cross Found at: x=935, y=476
# Offset: x=295, y=116
# Red Cross Found at: x=1028, y=630
# Offset: x=388, y=270
# Red Cross Found at: x=949, y=604
# Offset: x=309, y=244
# Red Cross Found at: x=923, y=382
# Offset: x=283, y=22
# Red Cross Found at: x=61, y=322
# Offset: x=-579, y=-38
# Red Cross Found at: x=69, y=263
# Offset: x=-571, y=-97
# Red Cross Found at: x=92, y=219
# Offset: x=-548, y=-141
# Red Cross Found at: x=1211, y=276
# Offset: x=571, y=-84
# Red Cross Found at: x=151, y=237
# Offset: x=-489, y=-123
# Red Cross Found at: x=127, y=187
# Offset: x=-513, y=-173
# Red Cross Found at: x=57, y=179
# Offset: x=-583, y=-181
# Red Cross Found at: x=152, y=152
# Offset: x=-488, y=-208
# Red Cross Found at: x=69, y=20
# Offset: x=-571, y=-340
# Red Cross Found at: x=612, y=575
# Offset: x=-28, y=215
# Red Cross Found at: x=1059, y=549
# Offset: x=419, y=189
# Red Cross Found at: x=1042, y=659
# Offset: x=402, y=299
# Red Cross Found at: x=972, y=608
# Offset: x=332, y=248
# Red Cross Found at: x=65, y=19
# Offset: x=-575, y=-341
# Red Cross Found at: x=19, y=526
# Offset: x=-621, y=166
# Red Cross Found at: x=157, y=235
# Offset: x=-483, y=-125
# Red Cross Found at: x=1078, y=198
# Offset: x=438, y=-162
# Red Cross Found at: x=126, y=189
# Offset: x=-514, y=-171
# Red Cross Found at: x=217, y=179
# Offset: x=-423, y=-181
# Red Cross Found at: x=612, y=575
# Offset: x=-28, y=215
# Red Cross Found at: x=1032, y=549
# Offset: x=392, y=189
# Red Cross Found at: x=1044, y=690
# Offset: x=404, y=330
# Red Cross Found at: x=958, y=509
# Offset: x=318, y=149
# Red Cross Found at: x=1243, y=389
# Offset: x=603, y=29
# Red Cross Found at: x=1220, y=362
# Offset: x=580, y=2
# Red Cross Found at: x=96, y=302
# Offset: x=-544, y=-58
# Red Cross Found at: x=79, y=272
# Offset: x=-561, y=-88
# Red Cross Found at: x=1138, y=251
# Offset: x=498, y=-109
# Red Cross Found at: x=191, y=262
# Offset: x=-449, y=-98
# Red Cross Found at: x=105, y=241
# Offset: x=-535, y=-119
# Red Cross Found at: x=140, y=248
# Offset: x=-500, y=-112
# Red Cross Found at: x=176, y=206
# Offset: x=-464, y=-154
# Red Cross Found at: x=1177, y=224
# Offset: x=537, y=-136
# Red Cross Found at: x=1204, y=166
# Offset: x=564, y=-194
# Red Cross Found at: x=749, y=644
# Offset: x=109, y=284
# Red Cross Found at: x=694, y=636
# Offset: x=54, y=276
# Red Cross Found at: x=881, y=590
# Offset: x=241, y=230
# Red Cross Found at: x=629, y=576
# Offset: x=-11, y=216
# Red Cross Found at: x=1065, y=545
# Offset: x=425, y=185
# Red Cross Found at: x=1054, y=693
# Offset: x=414, y=333
# Red Cross Found at: x=1028, y=635
# Offset: x=388, y=275
# Red Cross Found at: x=1110, y=576
# Offset: x=470, y=216
# Red Cross Found at: x=1248, y=180
# Offset: x=608, y=-180
# Red Cross Found at: x=84, y=96
# Offset: x=-556, y=-264
# Red Cross Found at: x=96, y=301
# Offset: x=-544, y=-59
# Red Cross Found at: x=199, y=251
# Offset: x=-441, y=-109
# Red Cross Found at: x=97, y=255
# Offset: x=-543, y=-105
# Red Cross Found at: x=1159, y=224
# Offset: x=519, y=-136
# Red Cross Found at: x=177, y=213
# Offset: x=-463, y=-147
# Red Cross Found at: x=128, y=228
# Offset: x=-512, y=-132
# Red Cross Found at: x=61, y=171
# Offset: x=-579, y=-189
# Red Cross Found at: x=208, y=169
# Offset: x=-432, y=-191
# Red Cross Found at: x=1034, y=145
# Offset: x=394, y=-215
# Red Cross Found at: x=739, y=645
# Offset: x=99, y=285
# Red Cross Found at: x=47, y=651
# Offset: x=-593, y=291
# Red Cross Found at: x=646, y=577
# Offset: x=6, y=217
# Red Cross Found at: x=1062, y=532
# Offset: x=422, y=172
# Red Cross Found at: x=1057, y=693
# Offset: x=417, y=333
# Red Cross Found at: x=1032, y=638
# Offset: x=392, y=278
# Red Cross Found at: x=1037, y=265
# Offset: x=397, y=-95
# Red Cross Found at: x=156, y=256
# Offset: x=-484, y=-104
# Red Cross Found at: x=17, y=110
# Offset: x=-623, y=-250
# Red Cross Found at: x=71, y=17
# Offset: x=-569, y=-343
# Red Cross Found at: x=47, y=680
# Offset: x=-593, y=320
# Red Cross Found at: x=889, y=589
# Offset: x=249, y=229
# Red Cross Found at: x=1093, y=551
# Offset: x=453, y=191
# Red Cross Found at: x=1030, y=626
# Offset: x=390, y=266
# Red Cross Found at: x=94, y=304
# Offset: x=-546, y=-56
# Red Cross Found at: x=106, y=246
# Offset: x=-534, y=-114
# Red Cross Found at: x=176, y=227
# Offset: x=-464, y=-133
# Red Cross Found at: x=40, y=660
# Offset: x=-600, y=300
# Red Cross Found at: x=614, y=574
# Offset: x=-26, y=214
# Red Cross Found at: x=639, y=583
# Offset: x=-1, y=223
# Red Cross Found at: x=1047, y=551
# Offset: x=407, y=191
# Red Cross Found at: x=1035, y=630
# Offset: x=395, y=270
# Red Cross Found at: x=1071, y=407
# Offset: x=431, y=47
# Red Cross Found at: x=1217, y=169
# Offset: x=577, y=-191
# Red Cross Found at: x=64, y=19
# Offset: x=-576, y=-341
# Red Cross Found at: x=177, y=325
# Offset: x=-463, y=-35
# Red Cross Found at: x=92, y=308
# Offset: x=-548, y=-52
# Red Cross Found at: x=105, y=244
# Offset: x=-535, y=-116
# Red Cross Found at: x=1024, y=214
# Offset: x=384, y=-146
# Red Cross Found at: x=174, y=236
# Offset: x=-466, y=-124
# Red Cross Found at: x=1105, y=162
# Offset: x=465, y=-198
# Red Cross Found at: x=726, y=638
# Offset: x=86, y=278
# Red Cross Found at: x=1092, y=549
# Offset: x=452, y=189
# Red Cross Found at: x=1035, y=684
# Offset: x=395, y=324
# Red Cross Found at: x=1023, y=639
# Offset: x=383, y=279
# Red Cross Found at: x=30, y=648
# Offset: x=-610, y=288
# Red Cross Found at: x=95, y=301
# Offset: x=-545, y=-59
# Red Cross Found at: x=70, y=254
# Offset: x=-570, y=-106
# Red Cross Found at: x=1024, y=218
# Offset: x=384, y=-142
# Red Cross Found at: x=215, y=178
# Offset: x=-425, y=-182
# Red Cross Found at: x=66, y=19
# Offset: x=-574, y=-341
# Red Cross Found at: x=728, y=642
# Offset: x=88, y=282
# Red Cross Found at: x=632, y=578
# Offset: x=-8, y=218
# Red Cross Found at: x=1068, y=546
# Offset: x=428, y=186
# Red Cross Found at: x=1008, y=647
# Offset: x=368, y=287
# Red Cross Found at: x=41, y=576
# Offset: x=-599, y=216
# Red Cross Found at: x=1122, y=300
# Offset: x=482, y=-60
# Red Cross Found at: x=1045, y=281
# Offset: x=405, y=-79
# Red Cross Found at: x=1074, y=268
# Offset: x=434, y=-92
# Red Cross Found at: x=73, y=260
# Offset: x=-567, y=-100
# Red Cross Found at: x=1121, y=249
# Offset: x=481, y=-111
# Red Cross Found at: x=190, y=241
# Offset: x=-450, y=-119
# Red Cross Found at: x=1032, y=210
# Offset: x=392, y=-150
# Red Cross Found at: x=161, y=228
# Offset: x=-479, y=-132
# Red Cross Found at: x=133, y=222
# Offset: x=-507, y=-138
# Red Cross Found at: x=62, y=22
# Offset: x=-578, y=-338
# Red Cross Found at: x=729, y=640
# Offset: x=89, y=280
# Red Cross Found at: x=63, y=579
# Offset: x=-577, y=219
# Red Cross Found at: x=619, y=577
# Offset: x=-21, y=217
# Red Cross Found at: x=1068, y=547
# Offset: x=428, y=187
# Red Cross Found at: x=1013, y=654
# Offset: x=373, y=294
# Red Cross Found at: x=1187, y=208
# Offset: x=547, y=-152
# Red Cross Found at: x=1250, y=365
# Offset: x=610, y=5
# Red Cross Found at: x=1131, y=300
# Offset: x=491, y=-60
# Red Cross Found at: x=1043, y=286
# Offset: x=403, y=-74
# Red Cross Found at: x=76, y=269
# Offset: x=-564, y=-91
# Red Cross Found at: x=195, y=241
# Offset: x=-445, y=-119
# Red Cross Found at: x=145, y=260
# Offset: x=-495, y=-100
# Red Cross Found at: x=55, y=22
# Offset: x=-585, y=-338
# Red Cross Found at: x=729, y=639
# Offset: x=89, y=279
# Red Cross Found at: x=1148, y=558
# Offset: x=508, y=198
# Red Cross Found at: x=1067, y=546
# Offset: x=427, y=186
# Red Cross Found at: x=1201, y=329
# Offset: x=561, y=-31
# Red Cross Found at: x=177, y=318
# Offset: x=-463, y=-42
# Red Cross Found at: x=1132, y=301
# Offset: x=492, y=-59
# Red Cross Found at: x=1040, y=287
# Offset: x=400, y=-73
# Red Cross Found at: x=73, y=277
# Offset: x=-567, y=-83
# Red Cross Found at: x=142, y=257
# Offset: x=-498, y=-103
# Red Cross Found at: x=109, y=243
# Offset: x=-531, y=-117
# Red Cross Found at: x=1157, y=231
# Offset: x=517, y=-129
# Red Cross Found at: x=1188, y=225
# Offset: x=548, y=-135
# ...
# Offset: x=-516, y=-153
# Red Cross Found at: x=253, y=194
# Offset: x=-387, y=-166
# Red Cross Found at: x=65, y=19
# Offset: x=-575, y=-341
# Red Cross Found at: x=1069, y=542
# Offset: x=429, y=182
# Red Cross Found at: x=1020, y=698
# Offset: x=380, y=338
# Red Cross Found at: x=1055, y=637
# Offset: x=415, y=277
# Red Cross Found at: x=1139, y=570
# Offset: x=499, y=210
# Red Cross Found at: x=1071, y=402
# Offset: x=431, y=42
# Red Cross Found at: x=44, y=382
# Offset: x=-596, y=22
# Red Cross Found at: x=1234, y=307
# Offset: x=594, y=-53
# Red Cross Found at: x=1135, y=243
# Offset: x=495, y=-117
# Red Cross Found at: x=153, y=219
# Offset: x=-487, y=-141
# Red Cross Found at: x=45, y=221
# Offset: x=-595, y=-139
# Red Cross Found at: x=301, y=211
# Offset: x=-339, y=-149
# Red Cross Found at: x=249, y=191
# Offset: x=-391, y=-169
# Red Cross Found at: x=84, y=170
# Offset: x=-556, y=-190
# Red Cross Found at: x=1017, y=185
# Offset: x=377, y=-175
# Red Cross Found at: x=67, y=18
# Offset: x=-573, y=-342
# Red Cross Found at: x=1070, y=542
# Offset: x=430, y=182
# Red Cross Found at: x=1053, y=632
# Offset: x=413, y=272
# Red Cross Found at: x=1141, y=568
# Offset: x=501, y=208
# Red Cross Found at: x=1224, y=365
# Offset: x=584, y=5
# Red Cross Found at: x=47, y=378
# Offset: x=-593, y=18
# Red Cross Found at: x=1235, y=311
# Offset: x=595, y=-49
# Red Cross Found at: x=255, y=282
# Offset: x=-385, y=-78
# Red Cross Found at: x=96, y=308
# Offset: x=-544, y=-52
# Red Cross Found at: x=26, y=266
# Offset: x=-614, y=-94
# Red Cross Found at: x=1051, y=268
# Offset: x=411, y=-92
# Red Cross Found at: x=242, y=207
# Offset: x=-398, y=-153
# Red Cross Found at: x=142, y=208
# Offset: x=-498, y=-152
# Red Cross Found at: x=76, y=158
# Offset: x=-564, y=-202
# Red Cross Found at: x=65, y=18
# Offset: x=-575, y=-342
# Red Cross Found at: x=207, y=695
# Offset: x=-433, y=335
# Red Cross Found at: x=613, y=576
# Offset: x=-27, y=216
# Red Cross Found at: x=1072, y=539
# Offset: x=432, y=179
# Red Cross Found at: x=1020, y=693
# Offset: x=380, y=333
# Red Cross Found at: x=1050, y=634
# Offset: x=410, y=274
# Red Cross Found at: x=1141, y=571
# Offset: x=501, y=211
# Red Cross Found at: x=1070, y=400
# Offset: x=430, y=40
# Red Cross Found at: x=1228, y=181
# Offset: x=588, y=-179
# Red Cross Found at: x=62, y=24
# Offset: x=-578, y=-336
# Red Cross Found at: x=43, y=380
# Offset: x=-597, y=20
# Red Cross Found at: x=1236, y=313
# Offset: x=596, y=-47
# Red Cross Found at: x=1179, y=291
# Offset: x=539, y=-69
# Red Cross Found at: x=258, y=281
# Offset: x=-382, y=-79
# Red Cross Found at: x=1180, y=241
# Offset: x=540, y=-119
# Red Cross Found at: x=150, y=218
# Offset: x=-490, y=-142
# Red Cross Found at: x=118, y=208
# Offset: x=-522, y=-152
# Red Cross Found at: x=1101, y=175
# Offset: x=461, y=-185
# Red Cross Found at: x=262, y=169
# Offset: x=-378, y=-191
# Red Cross Found at: x=1021, y=182
# Offset: x=381, y=-178
# Red Cross Found at: x=615, y=575
# Offset: x=-25, y=215
# Red Cross Found at: x=1067, y=539
# Offset: x=427, y=179
# Red Cross Found at: x=1049, y=637
# Offset: x=409, y=277
# Red Cross Found at: x=1141, y=563
# Offset: x=501, y=203
# Red Cross Found at: x=1049, y=420
# Offset: x=409, y=60
# Red Cross Found at: x=1072, y=400
# Offset: x=432, y=40
# Red Cross Found at: x=90, y=77
# Offset: x=-550, y=-283
# Red Cross Found at: x=63, y=23
# Offset: x=-577, y=-337
# Red Cross Found at: x=1239, y=314
# Offset: x=599, y=-46
# Red Cross Found at: x=258, y=280
# Offset: x=-382, y=-80
# Red Cross Found at: x=242, y=203
# Offset: x=-398, y=-157
# Red Cross Found at: x=172, y=203
# Offset: x=-468, y=-157
# Red Cross Found at: x=132, y=189
# Offset: x=-508, y=-171
# Red Cross Found at: x=66, y=164
# Offset: x=-574, y=-196
# Red Cross Found at: x=34, y=674
# Offset: x=-606, y=314
# Red Cross Found at: x=1067, y=536
# Offset: x=427, y=176
# Red Cross Found at: x=1053, y=634
# Offset: x=413, y=274
# Red Cross Found at: x=965, y=572
# Offset: x=325, y=212
# Red Cross Found at: x=1141, y=569
# Offset: x=501, y=209
# Red Cross Found at: x=1058, y=427
# Offset: x=418, y=67
# Red Cross Found at: x=1075, y=400
# Offset: x=435, y=40
# Red Cross Found at: x=1249, y=145
# Offset: x=609, y=-215
# Red Cross Found at: x=65, y=15
# Offset: x=-575, y=-345
# Red Cross Found at: x=1048, y=267
# Offset: x=408, y=-93
# Red Cross Found at: x=132, y=191
# Offset: x=-508, y=-169
# Red Cross Found at: x=1017, y=187
# Offset: x=377, y=-173
# Red Cross Found at: x=104, y=172
# Offset: x=-536, y=-188
# Red Cross Found at: x=231, y=179
# Offset: x=-409, y=-181
# Red Cross Found at: x=933, y=560
# Offset: x=293, y=200
# Red Cross Found at: x=617, y=575
# Offset: x=-23, y=215
# Red Cross Found at: x=1072, y=536
# Offset: x=432, y=176
# Red Cross Found at: x=1055, y=631
# Offset: x=415, y=271
# Red Cross Found at: x=65, y=13
# Offset: x=-575, y=-347
# Red Cross Found at: x=30, y=671
# Offset: x=-610, y=311
# Red Cross Found at: x=31, y=254
# Offset: x=-609, y=-106
# Red Cross Found at: x=1057, y=249
# Offset: x=417, y=-111
# Red Cross Found at: x=148, y=223
# Offset: x=-492, y=-137
# Red Cross Found at: x=19, y=222
# Offset: x=-621, y=-138
# Red Cross Found at: x=330, y=147
# Offset: x=-310, y=-213
# Red Cross Found at: x=80, y=156
# Offset: x=-560, y=-204
# Red Cross Found at: x=619, y=575
# Offset: x=-21, y=215
# Red Cross Found at: x=1070, y=539
# Offset: x=430, y=179
# Red Cross Found at: x=1059, y=636
# Offset: x=419, y=276
# Red Cross Found at: x=965, y=571
# Offset: x=325, y=211
# Red Cross Found at: x=1141, y=561
# Offset: x=501, y=201
# Red Cross Found at: x=63, y=14
# Offset: x=-577, y=-346
# Red Cross Found at: x=25, y=255
# Offset: x=-615, y=-105
# Red Cross Found at: x=1052, y=256
# Offset: x=412, y=-104
# Red Cross Found at: x=1194, y=232
# Offset: x=554, y=-128
# Red Cross Found at: x=143, y=224
# Offset: x=-497, y=-136
# Red Cross Found at: x=88, y=217
# Offset: x=-552, y=-143
# Red Cross Found at: x=241, y=207
# Offset: x=-399, y=-153
# Red Cross Found at: x=1140, y=239
# Offset: x=500, y=-121
# Red Cross Found at: x=1024, y=206
# Offset: x=384, y=-154
# Red Cross Found at: x=615, y=574
# Offset: x=-25, y=214
# Red Cross Found at: x=1065, y=539
# Offset: x=425, y=179
# Red Cross Found at: x=1047, y=657
# Offset: x=407, y=297
# Red Cross Found at: x=1057, y=612
# Offset: x=417, y=252
# Red Cross Found at: x=968, y=574
# Offset: x=328, y=214
# Red Cross Found at: x=1141, y=571
# Offset: x=501, y=211
# Red Cross Found at: x=1115, y=278
# Offset: x=475, y=-82
# Red Cross Found at: x=1215, y=317
# Offset: x=575, y=-43
# Red Cross Found at: x=35, y=671
# Offset: x=-605, y=311
# Red Cross Found at: x=21, y=346
# Offset: x=-619, y=-14
# Red Cross Found at: x=92, y=309
# Offset: x=-548, y=-51
# Red Cross Found at: x=22, y=302
# Offset: x=-618, y=-58
# Red Cross Found at: x=1065, y=234
# Offset: x=425, y=-126
# Red Cross Found at: x=243, y=200
# Offset: x=-397, y=-160
# Red Cross Found at: x=1048, y=149
# Offset: x=408, y=-211
# Red Cross Found at: x=1065, y=536
# Offset: x=425, y=176
# Red Cross Found at: x=1072, y=630
# Offset: x=432, y=270
# Red Cross Found at: x=1141, y=571
# Offset: x=501, y=211
# Red Cross Found at: x=1125, y=289
# Offset: x=485, y=-71
# Red Cross Found at: x=924, y=336
# Offset: x=284, y=-24
# Red Cross Found at: x=23, y=308
# Offset: x=-617, y=-52
# Red Cross Found at: x=293, y=254
# Offset: x=-347, y=-106
# Red Cross Found at: x=1145, y=205
# Offset: x=505, y=-155
# Red Cross Found at: x=1038, y=238
# Offset: x=398, y=-122
# Red Cross Found at: x=1063, y=206
# Offset: x=423, y=-154
# Red Cross Found at: x=244, y=199
# Offset: x=-396, y=-161
# Red Cross Found at: x=106, y=174
# Offset: x=-534, y=-186
# Red Cross Found at: x=285, y=166
# Offset: x=-355, y=-194
# Red Cross Found at: x=971, y=163
# Offset: x=331, y=-197
# Red Cross Found at: x=933, y=558
# Offset: x=293, y=198
# Red Cross Found at: x=1073, y=534
# Offset: x=433, y=174
# Red Cross Found at: x=1043, y=662
# Offset: x=403, y=302
# Red Cross Found at: x=1074, y=631
# Offset: x=434, y=271
# Red Cross Found at: x=1047, y=616
# Offset: x=407, y=256
# Red Cross Found at: x=1140, y=571
# Offset: x=500, y=211
# Red Cross Found at: x=1215, y=313
# Offset: x=575, y=-47
# Red Cross Found at: x=1181, y=296
# Offset: x=541, y=-64
# Red Cross Found at: x=1074, y=226
# Offset: x=434, y=-134
# Red Cross Found at: x=1244, y=192
# Offset: x=604, y=-168
# Red Cross Found at: x=76, y=270
# Offset: x=-564, y=-90
# Red Cross Found at: x=145, y=249
# Offset: x=-495, y=-111
# Red Cross Found at: x=251, y=210
# Offset: x=-389, y=-150
# Red Cross Found at: x=1086, y=160
# Offset: x=446, y=-200
# Red Cross Found at: x=222, y=158
# Offset: x=-418, y=-202
# Red Cross Found at: x=762, y=121
# Offset: x=122, y=-239
# Red Cross Found at: x=68, y=14
# Offset: x=-572, y=-346
# Red Cross Found at: x=615, y=578
# Offset: x=-25, y=218
# Red Cross Found at: x=1087, y=567
# Offset: x=447, y=207
# Red Cross Found at: x=1038, y=660
# Offset: x=398, y=300
# Red Cross Found at: x=1071, y=631
# Offset: x=431, y=271
# Red Cross Found at: x=1140, y=570
# Offset: x=500, y=210
# Red Cross Found at: x=1070, y=267
# Offset: x=430, y=-93
# Red Cross Found at: x=1199, y=303
# Offset: x=559, y=-57
# Red Cross Found at: x=1245, y=147
# Offset: x=605, y=-213
# Red Cross Found at: x=93, y=311
# Offset: x=-547, y=-49
# Red Cross Found at: x=79, y=262
# Offset: x=-561, y=-98
# Red Cross Found at: x=131, y=198
# Offset: x=-509, y=-162
# Red Cross Found at: x=247, y=209
# Offset: x=-393, y=-151
# Red Cross Found at: x=221, y=157
# Offset: x=-419, y=-203
# Red Cross Found at: x=65, y=15
# Offset: x=-575, y=-345
# Red Cross Found at: x=1071, y=538
# Offset: x=431, y=178
# Red Cross Found at: x=1037, y=636
# Offset: x=397, y=276
# Red Cross Found at: x=968, y=568
# Offset: x=328, y=208
# Red Cross Found at: x=1141, y=570
# Offset: x=501, y=210
# Red Cross Found at: x=1250, y=215
# Offset: x=610, y=-145
# Red Cross Found at: x=176, y=321
# Offset: x=-464, y=-39
# Red Cross Found at: x=95, y=298
# Offset: x=-545, y=-62
# Red Cross Found at: x=1164, y=215
# Offset: x=524, y=-145
# Red Cross Found at: x=424, y=181
# Offset: x=-216, y=-179
# Red Cross Found at: x=342, y=166
# Offset: x=-298, y=-194
# Red Cross Found at: x=233, y=175
# Offset: x=-407, y=-185
# Red Cross Found at: x=66, y=16
# Offset: x=-574, y=-344
# Red Cross Found at: x=39, y=70
# Offset: x=-601, y=-290
# Red Cross Found at: x=1066, y=567
# Offset: x=426, y=207
# Red Cross Found at: x=1044, y=653
# Offset: x=404, y=293
# Red Cross Found at: x=1053, y=642
# Offset: x=413, y=282
# Red Cross Found at: x=970, y=569
# Offset: x=330, y=209
# Red Cross Found at: x=1140, y=568
# Offset: x=500, y=208
# Red Cross Found at: x=1126, y=402
# Offset: x=486, y=42
# Red Cross Found at: x=63, y=16
# Offset: x=-577, y=-344
# Red Cross Found at: x=172, y=320
# Offset: x=-468, y=-40
# Red Cross Found at: x=286, y=284
# Offset: x=-354, y=-76
# Red Cross Found at: x=90, y=287
# Offset: x=-550, y=-73
# Red Cross Found at: x=179, y=227
# Offset: x=-461, y=-133
# Red Cross Found at: x=116, y=215
# Offset: x=-524, y=-145
# Red Cross Found at: x=1162, y=203
# Offset: x=522, y=-157
# Red Cross Found at: x=1126, y=182
# Offset: x=486, y=-178
# Red Cross Found at: x=977, y=182
# Offset: x=337, y=-178
# Red Cross Found at: x=238, y=170
# Offset: x=-402, y=-190
# Red Cross Found at: x=156, y=154
# Offset: x=-484, y=-206
# Red Cross Found at: x=210, y=692
# Offset: x=-430, y=332
# Red Cross Found at: x=635, y=582
# Offset: x=-5, y=222
# Red Cross Found at: x=565, y=562
# Offset: x=-75, y=202
# Red Cross Found at: x=1071, y=567
# Offset: x=431, y=207
# Red Cross Found at: x=1022, y=689
# Offset: x=382, y=329
# Red Cross Found at: x=1056, y=637
# Offset: x=416, y=277
# Red Cross Found at: x=1142, y=570
# Offset: x=502, y=210
# Red Cross Found at: x=1122, y=392
# Offset: x=482, y=32
# Red Cross Found at: x=81, y=102
# Offset: x=-559, y=-258
# Red Cross Found at: x=166, y=319
# Offset: x=-474, y=-41
# Red Cross Found at: x=999, y=257
# Offset: x=359, y=-103
# Red Cross Found at: x=245, y=218
# Offset: x=-395, y=-142
# Red Cross Found at: x=339, y=156
# Offset: x=-301, y=-204
# Red Cross Found at: x=234, y=160
# Offset: x=-406, y=-200
# Red Cross Found at: x=294, y=152
# Offset: x=-346, y=-208
# Red Cross Found at: x=1068, y=567
# Offset: x=428, y=207
# Red Cross Found at: x=1053, y=637
# Offset: x=413, y=277
# Red Cross Found at: x=1140, y=571
# Offset: x=500, y=211
# Red Cross Found at: x=1126, y=399
# Offset: x=486, y=39
# Red Cross Found at: x=86, y=70
# Offset: x=-554, y=-290
# Red Cross Found at: x=66, y=24
# Offset: x=-574, y=-336
# Red Cross Found at: x=262, y=295
# Offset: x=-378, y=-65
# Red Cross Found at: x=79, y=291
# Offset: x=-561, y=-69
# Red Cross Found at: x=1123, y=273
# Offset: x=483, y=-87
# Red Cross Found at: x=244, y=220
# Offset: x=-396, y=-140
# Red Cross Found at: x=61, y=179
# Offset: x=-579, y=-181
# Red Cross Found at: x=220, y=159
# Offset: x=-420, y=-201
# Red Cross Found at: x=270, y=166
# Offset: x=-370, y=-194
# Red Cross Found at: x=41, y=142
# Offset: x=-599, y=-218
# Red Cross Found at: x=613, y=575
# Offset: x=-27, y=215
# Red Cross Found at: x=1078, y=541
# Offset: x=438, y=181
# Red Cross Found at: x=1052, y=638
# Offset: x=412, y=278
# Red Cross Found at: x=977, y=572
# Offset: x=337, y=212
# Red Cross Found at: x=1140, y=570
# Offset: x=500, y=210
# Red Cross Found at: x=1262, y=258
# Offset: x=622, y=-102
# Red Cross Found at: x=1259, y=182
# Offset: x=619, y=-178
# Red Cross Found at: x=67, y=27
# Offset: x=-573, y=-333
# Red Cross Found at: x=47, y=628
# Offset: x=-593, y=268
# Red Cross Found at: x=259, y=297
# Offset: x=-381, y=-63
# Red Cross Found at: x=78, y=280
# Offset: x=-562, y=-80
# Red Cross Found at: x=1134, y=260
# Offset: x=494, y=-100
# Red Cross Found at: x=254, y=217
# Offset: x=-386, y=-143
# Red Cross Found at: x=133, y=187
# Offset: x=-507, y=-173
# Red Cross Found at: x=1030, y=168
# Offset: x=390, y=-192
# Red Cross Found at: x=57, y=180
# Offset: x=-583, y=-180
# Red Cross Found at: x=275, y=164
# Offset: x=-365, y=-196
# Red Cross Found at: x=726, y=613
# Offset: x=86, y=253
# Red Cross Found at: x=1079, y=569
# Offset: x=439, y=209
# Red Cross Found at: x=1056, y=635
# Offset: x=416, y=275
# Red Cross Found at: x=977, y=568
# Offset: x=337, y=208
# Red Cross Found at: x=1140, y=564
# Offset: x=500, y=204
# Red Cross Found at: x=1112, y=394
# Offset: x=472, y=34
# Red Cross Found at: x=1218, y=348
# Offset: x=578, y=-12
# Red Cross Found at: x=1259, y=251
# Offset: x=619, y=-109
# Red Cross Found at: x=1246, y=166
# Offset: x=606, y=-194
# Red Cross Found at: x=68, y=27
# Offset: x=-572, y=-333
# Red Cross Found at: x=262, y=298
# Offset: x=-378, y=-62
# Red Cross Found at: x=158, y=263
# Offset: x=-482, y=-97
# Red Cross Found at: x=82, y=283
# Offset: x=-558, y=-77
# Red Cross Found at: x=1038, y=247
# Offset: x=398, y=-113
# Red Cross Found at: x=1088, y=234
# Offset: x=448, y=-126
# Red Cross Found at: x=68, y=233
# Offset: x=-572, y=-127
# Red Cross Found at: x=140, y=181
# Offset: x=-500, y=-179
# Red Cross Found at: x=1023, y=172
# Offset: x=383, y=-188
# Red Cross Found at: x=262, y=192
# Offset: x=-378, y=-168
# Red Cross Found at: x=85, y=133
# Offset: x=-555, y=-227
# Red Cross Found at: x=693, y=629
# Offset: x=53, y=269
# Red Cross Found at: x=742, y=613
# Offset: x=102, y=253
# Red Cross Found at: x=626, y=573
# Offset: x=-14, y=213
# Red Cross Found at: x=1068, y=567
# Offset: x=428, y=207
# Red Cross Found at: x=1060, y=640
# Offset: x=420, y=280
# Red Cross Found at: x=1111, y=393
# Offset: x=471, y=33
# Red Cross Found at: x=1204, y=323
# Offset: x=564, y=-37
# Red Cross Found at: x=157, y=313
# Offset: x=-483, y=-47
# Red Cross Found at: x=1123, y=286
# Offset: x=483, y=-74
# Red Cross Found at: x=152, y=262
# Offset: x=-488, y=-98
# Red Cross Found at: x=86, y=283
# Offset: x=-554, y=-77
# Red Cross Found at: x=1087, y=236
# Offset: x=447, y=-124
# Red Cross Found at: x=1174, y=224
# Offset: x=534, y=-136
# Red Cross Found at: x=246, y=218
# Offset: x=-394, y=-142
# Red Cross Found at: x=140, y=195
# Offset: x=-500, y=-165
# Red Cross Found at: x=269, y=183
# Offset: x=-371, y=-177
# Red Cross Found at: x=1011, y=168
# Offset: x=371, y=-192
# Red Cross Found at: x=113, y=157
# Offset: x=-527, y=-203
# Red Cross Found at: x=136, y=133
# Offset: x=-504, y=-227
# Red Cross Found at: x=87, y=129
# Offset: x=-553, y=-231
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 66
#      59                 print(f"Offset: x={offset_x}, y={offset_y}")
#      61     # Display the processed frame
#      62     # Display the video feed
#      63     # cv2.imshow("Red Cross Detection", frame)
#      64
#      65     # Break loop on 'q' key press
# ---> 66     if cv2.waitKey(1) & 0xFF == ord('q'):
#      67         break
#      69 cap.release()
#
# KeyboardInterrupt:

# %% [markdown]
# Litreature
# - video of drone Face tracking part
# https://www.youtube.com/watch?v=LmEcyQnfpDA
#
# - cv2 github repo to fetch the datasets

# %%
# FACE TRACKING - this works very well

import cv2
import numpy as np

# Detecting a face
def findFace(img):
    faseCascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")
    imgGray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = faseCascade.detectMultiScale(imgGray, 1.2, 8)

    myFaceList = []
    myFaceListArea = []

    for(x, y, w, h) in faces:
        cv2.rectangle(img, (x, y), (x + w, y + h), (0, 0, 255), 2)
        cx = x + w//2
        cy = y + h//2
        area = w*h
        cv2.circle(img, (cx, cy), 5, (0, 255, 0), cv2.FILLED)
        myFaceList.append((cx, cy, area))
        myFaceListArea.append(area)
    
    if len(myFaceList)!= 0:
        i = myFaceListArea.index(max(myFaceListArea))
        return img, [myFaceList[i], myFaceListArea[i]]
    
    # Default return to prevent errors
    return img, [[0, 0], 0]
    
# def trackFace(me, info, w, pidf, pError):
#     return


cap = cv2.VideoCapture(0)

while True:
    _, img = cap.read()
    img, info = findFace(img)
    print(f'Area: {info[1]}, Center: {info[0]}')
    cv2.imshow("Face Tracking", img)
    cv2.waitKey(1)

# %%
# This is detecting clocks as well as people

import cv2
import numpy as np

# Detecting a person
def findPerson(img):
    personCascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_upperbody.xml")
    imgGray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    persons = personCascade.detectMultiScale(imgGray, 1.1, 4)  # Adjust scaleFactor & minNeighbors if needed

    myPersonList = []
    myPersonListArea = []

    for (x, y, w, h) in persons:
        cv2.rectangle(img, (x, y), (x + w, y + h), (0, 0, 255), 2)
        cx = x + w // 2
        cy = y + h // 2
        area = w * h
        cv2.circle(img, (cx, cy), 5, (0, 255, 0), cv2.FILLED)
        myPersonList.append((cx, cy))
        myPersonListArea.append(area)

    if len(myPersonList) != 0:
        i = myPersonListArea.index(max(myPersonListArea))  # Select largest detected person
        return img, [myPersonList[i], myPersonListArea[i]]

    return img, [[0, 0], 0]  # Default return to prevent errors

cap = cv2.VideoCapture(0)

while True:
    _, img = cap.read()
    img, info = findPerson(img)
    print(f'Area: {info[1]}, Center: {info[0]}')

    cv2.imshow("Person Detection", img)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break  # Press 'q' to exit

cap.release()
cv2.destroyAllWindows()

# %%
import requests

DJI_ACCESS_TOKEN = "your_dji_cloud_api_access_token"
MEDIA_URL = "https://api.dji.com/v1/media"

headers = {"Authorization": f"Bearer {DJI_ACCESS_TOKEN}"}
response = requests.get(MEDIA_URL, headers=headers)

if response.status_code == 200:
    print(response.json())  # List of media files on the drone
else:
    print("Error accessing DJI Cloud API:", response.text)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/util/connection.py:72, in create_connection(address, timeout, source_address, socket_options)
#      68     return six.raise_from(
#      69         LocationParseError(u"'%s', label empty or too long" % host), None
#      70     )
# ---> 72 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      73     af, socktype, proto, canonname, sa = res
#
# File ~/anaconda3/lib/python3.11/socket.py:962, in getaddrinfo(host, port, family, type, proto, flags)
#     961 addrlist = []
# --> 962 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     963     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:403, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     402 try:
# --> 403     self._validate_conn(conn)
#     404 except (SocketTimeout, BaseSSLError) as e:
#     405     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:1053, in HTTPSConnectionPool._validate_conn(self, conn)
#    1052 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1053     conn.connect()
#    1055 if not conn.is_verified:
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/connection.py:363, in HTTPSConnection.connect(self)
#     361 def connect(self):
#     362     # Add certificate verification
# --> 363     self.sock = conn = self._new_conn()
#     364     hostname = self.host
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/connection.py:186, in HTTPConnection._new_conn(self)
#     185 except SocketError as e:
# --> 186     raise NewConnectionError(
#     187         self, "Failed to establish a new connection: %s" % e
#     188     )
#     190 return conn
#
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x108814d50>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:798, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     796     e = ProtocolError("Connection aborted.", e)
# --> 798 retries = retries.increment(
#     799     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     800 )
#     801 retries.sleep()
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/util/retry.py:592, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     591 if new_retry.is_exhausted():
# --> 592     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     594 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='api.dji.com', port=443): Max retries exceeded with url: /v1/media (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x108814d50>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[2], line 7
#       4 MEDIA_URL = "https://api.dji.com/v1/media"
#       6 headers = {"Authorization": f"Bearer {DJI_ACCESS_TOKEN}"}
# ----> 7 response = requests.get(MEDIA_URL, headers=headers)
#       9 if response.status_code == 200:
#      10     print(response.json())  # List of media files on the drone
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/adapters.py:519, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     515     if isinstance(e.reason, _SSLError):
#     516         # This branch is for urllib3 v1.22 and later.
#     517         raise SSLError(e, request=request)
# --> 519     raise ConnectionError(e, request=request)
#     521 except ClosedPoolError as e:
#     522     raise ConnectionError(e, request=request)
#
# ConnectionError: HTTPSConnectionPool(host='api.dji.com', port=443): Max retries exceeded with url: /v1/media (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x108814d50>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))

# %% [markdown]
# Challenges and Considerations -- things to check
# - Latency: Ensure minimal delay between detecting the red spot and sending commands.
# - Stability: Fine-tune thresholds for red detection to avoid false positives.
# - Safety: Test in a controlled environment to ensure predictable movements.
# - Camera Feed Access: If using the drone’s camera feed, ensure you can stream it to your processing device.
